# %%
#uploading required libraries and COVID-19 Coronavirus data set.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\pavi2\Downloads\COVID-19 Coronavirus.csv")
df
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 0          Afghanistan                Afghanistan                     AFG
# 1              Albania                    Albania                     ALB
# 2              Algeria                    Algeria                     DZA
# 3              Andorra                    Andorra                     AND
# 4               Angola                     Angola                     AGO
# ..                 ...                        ...                     ...
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %%
#check the shape
df.shape
# Out:
# (225, 10)

# %%
#check head
df.head()
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 3      Andorra      Andorra                     AND       77481    Europe
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
# 2       265691          6874               5873                152
# 3        40024           153             516565               1975
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 1          1.275058
# 2          2.587216
# 3          0.382271
# ...

# %%
#check tail
df.tail()
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# 220       10894   Oceania          454             7              41674
# 221      623031    Africa           10             1                 16
# 222    30975258      Asia        11806          2143                381
# 223    19284482    Africa       317076          3967              16442
# 224    15241601    Africa       246525          5446              16174
#
#      Tot Deaths/1M pop  Death percentage
# 220                643          1.541850
# ...

# %%
#check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  225 non-null    object
#  1   Other names              224 non-null    object
#  2   ISO 3166-1 alpha-3 CODE  225 non-null    object
#  3   Population               225 non-null    int64
#  4   Continent                225 non-null    object
#  5   Total Cases              225 non-null    int64
#  6   Total Deaths             225 non-null    int64
#  7   Tot Cases//1M pop        225 non-null    int64
#  8   Tot Deaths/1M pop        225 non-null    int64
#  9   Death percentage         225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %%
#check missing values
df.isnull().sum()
# Out:
# Country                    0
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# Tot Cases//1M pop          0
# Tot Deaths/1M pop          0
# Death percentage           0
# dtype: int64

# %%
#so we have one missing values

# %%
# check row which contains null values (Hint axis=1)
df[df.isna().any(axis=1)]
# Out:
#         Country Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 135  Montenegro         NaN                     MNE      628205    Europe
#
#      Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 135       233326          2705             371417               4306
#
#      Death percentage
# 135          1.159322

# %%
#fill null value with most suitable value (hint to replace,use inplace=True) replacing Nan with Montenegro
df.fillna('Montenegro',inplace=True)

# %%
#sanity check weather null values are replaced or not checking weather it is replaced or not
df.loc[135]
# Out:
# Country                    Montenegro
# Other names                Montenegro
# ISO 3166-1 alpha-3 CODE           MNE
# Population                     628205
# Continent                      Europe
# Total Cases                    233326
# Total Deaths                     2705
# Tot Cases//1M pop              371417
# Tot Deaths/1M pop                4306
# Death percentage             1.159322
# Name: 135, dtype: object

# %%
#check stats information of data set.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            225 non-null    object
#  1   Other names        225 non-null    object
#  2   Iso_Code           225 non-null    object
#  3   Population         225 non-null    int64
#  4   Continent          225 non-null    object
#  5   Total Cases        225 non-null    int64
#  6   Total Deaths       225 non-null    int64
#  7   Tot Cases//1M pop  225 non-null    int64
#  8   Tot Deaths/1M pop  225 non-null    int64
#  9   Death percentage   225 non-null    float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 17.7+ KB

# %%
# rename column iso 3166-1 alpha 3 CODE to Iso_Code
df.rename(columns={"ISO 3166-1 alpha-3 CODE": "Iso_Code"}, inplace=True)
df
# Out:
#                Country                Other names Iso_Code  Population  \
# 0          Afghanistan                Afghanistan      AFG    40462186
# 1              Albania                    Albania      ALB     2872296
# 2              Algeria                    Algeria      DZA    45236699
# 3              Andorra                    Andorra      AND       77481
# 4               Angola                     Angola      AGO    34654212
# ..                 ...                        ...      ...         ...
# 220  Wallis and Futuna  Wallis and Futuna Islands      WLF       10894
# 221     Western Sahara             Western Sahara    ESHÂ       623031
# 222              Yemen                      Yemen      YEM    30975258
# 223             Zambia                     Zambia      ZMB    19284482
# 224           Zimbabwe                   Zimbabwe      ZWE    15241601
#
#     Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %%
# top 5 countries which have more number of covid cases (hint use df.nlargest)
top_countries_covid_cases = df.nlargest(5, 'Total Cases')
top_countries_covid_cases
# Out:
#      Country               Other names Iso_Code  Population  \
# 214      USA  United States of America      USA   334400597
# 92     India                     India      IND  1403754381
# 26    Brazil                    Brazil      BRA   215204501
# 70    France                    France      FRA    65526369
# 76   Germany                   Germany      DEU    84252947
#
#                            Continent  Total Cases  Total Deaths  \
# 214                 Northern America     81839052       1008222
# 92                              Asia     43029044        521388
# 26   Latin America and the Caribbean     29999816        660269
# 70                            Europe     25997852        142506
# 76                            Europe     21646375        130563
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 214             244734               3015          1.231957
# 92               30653                371          1.211712
# ...

# %%
#plot bar graph for top 5 countries
plt.figure(figsize=(10, 6))
plt.bar(top_countries_covid_cases['Country'], top_countries_covid_cases['Total Cases'], color='skyblue')
plt.title('Top 5 Countries with the Most COVID Cases')
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()

# %%
# least 5 countries which have least number of covid cases
least_countries_covid_cases = df.nsmallest(5,'Total Cases')
least_countries_covid_cases
# Out:
#               Country                       Other names Iso_Code  Population  \
# 131        Micronesia  Micronesia (Federated States of)      FSM      117134
# 168      Saint Helena                      Saint Helena      SHN        6109
# 125  Marshall Islands                  Marshall Islands      MHL       59889
# 148              Niue                              Niue      NIU        1645
# 221    Western Sahara                    Western Sahara    ESHÂ       623031
#
#     Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# 131   Oceania            1             0                  9
# 168    Africa            2             0                327
# 125   Oceania            7             0                117
# 148   Oceania            7             0               4255
# 221    Africa           10             1                 16
#
#      Tot Deaths/1M pop  Death percentage
# 131                  0               0.0
# 168                  0               0.0
# ...

# %%
#draw bar graph of least 5 countries
plt.figure(figsize=(10, 6))
plt.bar(least_countries_covid_cases['Country'], least_countries_covid_cases['Total Cases'], color='lightcoral')
plt.title('Least 5 Countries with the Least COVID Cases')
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()

# %%
#top 5 countries which have more number of covid Deaths
more_death = df.nlargest(5,"Total Deaths") 
more_death
# Out:
#     Country               Other names Iso_Code  Population  \
# 214     USA  United States of America      USA   334400597
# 26   Brazil                    Brazil      BRA   215204501
# 92    India                     India      IND  1403754381
# 165  Russia        Russian Federation      RUS   146044010
# 130  Mexico                    Mexico      MEX   131303955
#
#                            Continent  Total Cases  Total Deaths  \
# 214                 Northern America     81839052       1008222
# 26   Latin America and the Caribbean     29999816        660269
# 92                              Asia     43029044        521388
# 165                           Europe     17896866        369708
# 130  Latin America and the Caribbean      5665376        323212
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 214             244734               3015          1.231957
# 26              139401               3068          2.200910
# ...

# %%
#plot bar graph for top 5 countries which have more number of covid Deaths
plt.figure(figsize=(10, 6))
plt.bar(more_death['Country'], more_death['Total Cases'], color='lightcoral')
plt.title('Top 5 Countries with the Most COVID Cases Death')
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()

# %%
#5 countries which have least number of covid Death
less_death = df.nsmallest(5,"Total Deaths") 
less_death
# Out:
#               Country                                 Other names Iso_Code  \
# 46       Cook Islands                                Cook Islands      COK
# 67   Falkland Islands                 Falkland Islands (Malvinas)      FLK
# 118             Macao  China, Macao Special Administrative Region      MAC
# 125  Marshall Islands                            Marshall Islands      MHL
# 131        Micronesia            Micronesia (Federated States of)      FSM
#
#      Population                        Continent  Total Cases  Total Deaths  \
# 46        17592                          Oceania         2118             0
# 67         3657  Latin America and the Caribbean          123             0
# 118      664828                             Asia           82             0
# 125       59889                          Oceania            7             0
# 131      117134                          Oceania            1             0
#
# ...

# %%
#Death percentage
#top 5 countries which have more number of covid  Death percentage 
death_percentage= df.nlargest(5,"Death percentage")
death_percentage
# Out:
#             Country     Other names Iso_Code  Population  \
# 222           Yemen           Yemen      YEM    30975258
# 221  Western Sahara  Western Sahara    ESHÂ       623031
# 193           Sudan           Sudan      SDN    45640385
# 158            Peru            Peru      PER    33775745
# 130          Mexico          Mexico      MEX   131303955
#
#                            Continent  Total Cases  Total Deaths  \
# 222                             Asia        11806          2143
# 221                           Africa           10             1
# 193                           Africa        61955          4907
# 158  Latin America and the Caribbean      3548559        212328
# 130  Latin America and the Caribbean      5665376        323212
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 222                381                 69         18.151787
# 221                 16                  2         10.000000
# ...

# %%
#plot bar graph for top 5 countries which have more number of covid  Death percentage 
plt.figure(figsize=(10, 6))
plt.bar(death_percentage['Country'], death_percentage['Total Cases'], color='lightcoral')
plt.title('Top 5 Countries with the most COVID Cases Death Percentage')
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()

# %%
#continent wise cases (hint use group by)
continent_wise_cases = df.groupby('Continent')['Total Cases'].sum().reset_index()
continent_wise_cases
# Out:
#                          Continent  Total Cases
# 0                           Africa     11764207
# 1                             Asia    140957179
# 2                           Europe    180332483
# 3  Latin America and the Caribbean     67509231
# 4                 Northern America     85364770
# 5                          Oceania      5647957

# %%
#draw bar plot for continent wise case
plt.figure(figsize=(10, 6))
plt.bar(continent_wise_cases['Continent'], continent_wise_cases['Total Cases'], color='green')
plt.title('Continent-wise COVID Cases')
plt.xlabel('Continent')
plt.ylabel('Total Cases')
plt.show()

# %%
#find relationship between Population and total cases.Comment  on outliers
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Population', y='Total Cases', data=df)
plt.title('Relationship between Population and Total Cases')
plt.xlabel('Population')
plt.ylabel('Total Cases')
plt.show()

# Calculate correlation coefficient
correlation_coefficient = df['Population'].corr(df['Total Cases'])
print(f'Correlation Coefficient: {correlation_coefficient}')


plt.figure(figsize=(10, 6))
sns.boxplot(x='Total Cases', data=df)
plt.title('Box Plot of Total Cases')
plt.show()
# Out:
# Correlation Coefficient: 0.4306868580526075

# %%
#OUTLIERS ARE PRESENT
